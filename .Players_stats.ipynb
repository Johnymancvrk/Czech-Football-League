# %% [markdown]
# ## In this file, we wrote a class which scrapes statistics about the players and converts it into a data frame and csv file.

# %% [markdown]
# ### First of all, necessary packages were imported.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import csv
import numpy as np

# %% [markdown]
# ### Further, we built a class which takes a url as a single input and creates a rough data frame that can be saved as a csv when calling the second inner function. Check the doc strings for a better compehension.

# %%
class ScrapeURL:
    '''
    This class takes one input - the url - and when calling further functions it creates a rough data frame
    which is then written to a csv.
    '''
    def __init__(self,link):
        self.link = link
        res = requests.get(self.link)
        comm = re.compile("<!--|-->")
        soup = BeautifulSoup(comm.sub("",res.text),'lxml')
        self.soup = soup
        self.Player_stats = Player_stats
    
    def scrapeURL(self):
        '''
        Scrapes the webpage and saves it in a data frame.
        '''
        all_tables = self.soup.findAll("tbody")
        player_table = all_tables[1]
        features_wanted_player = ["player","nationality","position","squad","age","birth_year","games","games_starts","minutes","goals","assists","pens_made","pens_att","cards_yellow","cards_red","goals_per90","assists_per90","goals_assists_per90","goals_pens_per90","goals_assists_pens_per90",]
        Player_stats = pd.DataFrame(columns = features_wanted_player, index = np.arange(454))
        rows_player = player_table.find_all('tr')
        c = 0
        for row in rows_player:

            if(row.find('th',{"scope":"row"}) != None):
                for f in features_wanted_player:
                    Player_stats.loc[c,f] = row.find("td",{"data-stat": f}).text
            c = c + 1
        return Player_stats
    def to_csv(self):
        '''
        Creates a csv file from the data frame.
        '''
        self.Player_stats.to_csv("Player_stats.csv")

# %% [markdown]
# ### In the following cell, the class is tested.

# %%
url = 'https://fbref.com/en/comps/66/stats/Czech-First-League-Stats'
my = ScrapeURL(url)
my.scrapeURL().head()
# Out:
#                  player nationality position           squad     age  \
# 0           Marko Alvir      hr CRO       MF  Viktoria Plzeň  26-255
# 1        Emmanuel Antwi      gh GHA       DF         Příbram  24-239
# 2    Oleksandr Azatskyi      ua UKR       DF   Baník Ostrava  26-352
# 3           Pavol Bajza      sk SVK       GK        Slovácko  29-117
# 4           Jakub Barac      cz CZE       MF  Slovan Liberec  24-148
# ..                  ...         ...      ...             ...     ...
# 466          David Zima      cz CZE       DF   Slavia Prague  20-052
# 468        Patrik Žitný      cz CZE       MF         Teplice  21-344
# 469       Ondřej Zmrzlý      cz CZE       MF   Sigma Olomouc  21-252
# 470        Filip Zorvan      cz CZE       MF         Příbram  24-267
# 471        Bojan Đorđić      ba BIH       FW           Opava  26-218
#
#     birth_year games games_starts minutes goals assists pens_made pens_att  \
# ...
